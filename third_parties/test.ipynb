# %%
import requests

api_key = 'cvy04uhRAVru2GVhD6ETsw'
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
params = {
    'linkedin_profile_url': 'https://www.linkedin.com/in/amirstm/',
    'extra': 'include',
    'github_profile_id': 'include',
    'facebook_profile_id': 'include',
    'twitter_profile_id': 'include',
    'personal_contact_number': 'include',
    'personal_email': 'include',
    'inferred_salary': 'include',
    'skills': 'include',
    'use_cache': 'if-present',
    'fallback_to_cache': 'on-error',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
print(response.json())
# Out:
# {'public_identifier': 'amirstm', 'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/amirstm/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241223%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241223T074819Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=8afb96b63c84bcb4075b93d8db3729eb5276c3374044e390010a0a1dee92149e', 'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/amirstm/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241223%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241223T074819Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=554e3e83b101ae00b223932042471c0e0c661d4a0a97d53f53f8e33b2f3a7adf', 'first_name': 'Amir', 'last_name': 'Zare', 'full_name': 'Amir Zare', 'follower_count': None, 'occupation': 'Olympiad Instructor at Helli 4&5, Karaj Soltani 1&3, Karaj Farzanegan, Shiraz Dastgheib, and several other highschools', 'headline': 'Co-founder & CFO at Arka Equities & Securities', 'summary': None, 'country': 'IR', 'country_full_name': 'Iran', 'city': None, 'state': None, 'experiences': [{'starts_at': {'day': 1, 'month': 9, 'year': 2012}, 'ends_at': {'day': 30, 'month': 9, 'year': 2018}, 'company': 'Helli 4&5, Karaj Soltani 1&3, Karaj Farzanegan, Shiraz Dastgheib, and several other highschools', 'company_linkedin_profile_url': None, 'company_facebook_profile_url': None, 'title': 'Olympiad Instructor', 'description': None, 'location': 'Iran', 'logo_url': None}, {'starts_at': {'day': 1, 'month': 6, 'year': 2016}, 'ends_at': {'day': 30, 'month': 9, 'year': 2016}, 'company': 'Azin Khodro Industrial Group', 'company_linkedin_profile_url': 'https://ir.linkedin.com/company/azin-khodro-co', 'company_facebook_profile_url': None, 'title': 'Intern', 'description': None, 'location': None, 'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/azin-khodro-co/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241223%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241223T074820Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=ea92040ebc51701851e5efb35a15c9e662f3d2a83e7d16b6292cd9ba18d860f7'}, {'starts_at': {'day': 1, 'month': 10, 'year': 2015}, 'ends_at': {'day': 29, 'month': 2, 'year': 2016}, 'company': 'Sharif University of Technology', 'company_linkedin_profile_url': 'https://ir.linkedin.com/company/sharif-university-of-technology', 'company_facebook_profile_url': None, 'title': 'Teaching Assistant', 'description': None, 'location': None, 'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/sharif-university-of-technology/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241223%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241223T074820Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=ddb4dbac4b0ccbfa17410ab7c06cc3e1cf01bcec9aff8caf33c132ddd36b8485'}], 'education': [{'starts_at': {'day': 1, 'month': 1, 'year': 2018}, 'ends_at': {'day': 31, 'month': 12, 'year': 2021}, 'field_of_study': 'Finance, General', 'degree_name': 'Master of Business Administration - MBA', 'school': 'Sharif University of Technology', 'school_linkedin_profile_url': 'https://ir.linkedin.com/school/sharif-university-of-technology/', 'school_facebook_profile_url': None, 'description': None, 'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/sharif-university-of-technology/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241223%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241223T074820Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=ddb4dbac4b0ccbfa17410ab7c06cc3e1cf01bcec9aff8caf33c132ddd36b8485', 'grade': None, 'activities_and_societies': None}, {'starts_at': {'day': 1, 'month': 1, 'year': 2013}, 'ends_at': {'day': 31, 'month': 12, 'year': 2018}, 'field_of_study': 'Physics', 'degree_name': 'Bachelor ...
